# %%
#import statements
import os
import json
import pandas as pd
import sqlite3

# %%
# Check if the pulse folder is present
print("pulse" in os.listdir())
# Out:
# True

# %%
# List contents of the dataset folder
os.listdir("pulse/data")
# Out:
# ['aggregated', 'map', 'top']

# %%
path = "./pulse/data/aggregated/transaction/country/india/state"
Agg_state_list = os.listdir(path)
Agg_state_list
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
#Aggregated transaction
path="./pulse/data/aggregated/transaction/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
clm={'State':[],
     'Year':[],
     'Quarter':[],
     'Transaction_type':[],
     'transaction_count':[],
     'transaction_amount':[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i) #lists aggregated year 
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r') #opening the file in the read only mode
            d=json.load(Data)
            for z in d['data']['transactionData']:#Getting into transaction list
                Name=z['name']
                count=z['paymentInstruments'][0]['count']
                amount=z['paymentInstruments'][0]['amount']
                #appending details into the clm list
                clm['Transaction_type'].append(Name)
                clm['transaction_count'].append(count)
                clm['transaction_amount'].append(amount)
                clm['State'].append(i)
                clm['Year'].append(j)
                clm['Quarter'].append(int(k.strip('.json')))#removes .json 
#dataframe
Agg_Trans=pd.DataFrame(clm)

# %%
Agg_Trans
# Out:
#                           State  Year  Quarter          Transaction_type  \
# 0     andaman-&-nicobar-islands  2018        1  Recharge & bill payments
# 1     andaman-&-nicobar-islands  2018        1     Peer-to-peer payments
# 2     andaman-&-nicobar-islands  2018        1         Merchant payments
# 3     andaman-&-nicobar-islands  2018        1        Financial Services
# 4     andaman-&-nicobar-islands  2018        1                    Others
# ...                         ...   ...      ...                       ...
# 5029                west-bengal  2024        4         Merchant payments
# 5030                west-bengal  2024        4     Peer-to-peer payments
# 5031                west-bengal  2024        4  Recharge & bill payments
# 5032                west-bengal  2024        4        Financial Services
# 5033                west-bengal  2024        4                    Others
#
#       transaction_count  transaction_amount
# 0                  4200        1.845307e+06
# ...

# %%
len(Agg_Trans['State'].unique())
# Out:
# 36

# %%
#Aggregated Insurance
path="./pulse/data/aggregated/insurance/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
clm={'State':[],
     'Year':[],
     'Quarter':[],
     'Transaction_type':[],
     'transaction_count':[],
     'transaction_amount':[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i) #lists aggregated year 
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r') #opening the file in the read only mode
            d=json.load(Data)
            for z in d['data']['transactionData']:#Getting into transaction list
                Name=z['name']
                count=z['paymentInstruments'][0]['count']
                amount=z['paymentInstruments'][0]['amount']
                #appending details into the clm list
                clm['Transaction_type'].append(Name)
                clm['transaction_count'].append(count)
                clm['transaction_amount'].append(amount)
                clm['State'].append(i)
                clm['Year'].append(j)
                clm['Quarter'].append(int(k.strip('.json')))#removes .json 
#dataframe
Agg_Insurance=pd.DataFrame(clm)

# %%
Agg_Insurance
# Out:
#                          State  Year  Quarter Transaction_type  \
# 0    andaman-&-nicobar-islands  2020        2        Insurance
# 1    andaman-&-nicobar-islands  2020        3        Insurance
# 2    andaman-&-nicobar-islands  2020        4        Insurance
# 3    andaman-&-nicobar-islands  2021        1        Insurance
# 4    andaman-&-nicobar-islands  2021        2        Insurance
# ..                         ...   ...      ...              ...
# 677                west-bengal  2023        4        Insurance
# 678                west-bengal  2024        1        Insurance
# 679                west-bengal  2024        2        Insurance
# 680                west-bengal  2024        3        Insurance
# 681                west-bengal  2024        4        Insurance
#
#      transaction_count  transaction_amount
# 0                    6              1360.0
# 1                   41             15380.0
# 2                  124            157975.0
# ...

# %%
#Aggregated User
path="./pulse/data/aggregated/user/country/india/state/"
Agg_state_list=os.listdir(path)
Agg_state_list
clm={'State':[],
     'Year':[],
     'Quarter':[],
     'Aggregated_type':[],
     'Aggregated_count':[],
     'Aggregated_percentage':[]}
for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i) #lists aggregated year 
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r') #opening the file in the read only mode
            d=json.load(Data)
            aggregated = d.get('data', {}).get('aggregated', {})
            Name = aggregated.get('registeredUsers', 'N/A')
            count = aggregated.get('appOpens', 0)
            amount = 0  # If there's no 'percentage', set a default
            clm['Aggregated_type'].append(Name)
            clm['Aggregated_count'].append(count)
            clm['Aggregated_percentage'].append(amount)
            clm['State'].append(i)
            clm['Year'].append(j)
            clm['Quarter'].append(int(k.strip('.json')))#removes .json 
#dataframe
Agg_user=pd.DataFrame(clm)

# %%
print(aggregated.keys())
# Out:
# dict_keys(['registeredUsers', 'appOpens'])

# %%
Agg_user
# Out:
#                           State  Year  Quarter  Aggregated_type  \
# 0     andaman-&-nicobar-islands  2018        1             6740
# 1     andaman-&-nicobar-islands  2018        2             9405
# 2     andaman-&-nicobar-islands  2018        3            12149
# 3     andaman-&-nicobar-islands  2018        4            15222
# 4     andaman-&-nicobar-islands  2019        1            18596
# ...                         ...   ...      ...              ...
# 1003                west-bengal  2023        4         30064546
# 1004                west-bengal  2024        1         31306843
# 1005                west-bengal  2024        2         32540397
# 1006                west-bengal  2024        3         33612828
# 1007                west-bengal  2024        4         34750181
#
#       Aggregated_count  Aggregated_percentage
# 0                    0                      0
# 1                    0                      0
# 2                    0                      0
# ...

# %%
# Define path
path = "./pulse/data/map/insurance/hover/country/india/state/"

# List of states
Map_state_list = os.listdir(path)

# Dictionary to collect data
clm = {
    'State': [],
    'Year': [],
    'Quarter': [],
    'Metric_type': [],
    'Metric_count': [],
    'Metric_amount': []
}

# Looping through states
for i in Map_state_list:
    p_i = os.path.join(path, i) + "/"
    Map_yr = os.listdir(p_i)  # list of years
    for j in Map_yr:
        p_j = os.path.join(p_i, j) + "/"
        Map_yr_list = os.listdir(p_j)  # list of quarters
        for k in Map_yr_list:
            p_k = os.path.join(p_j, k)
            with open(p_k, 'r') as Data:  # Using 'with' to open files safely
                d = json.load(Data)
                for z in d['data']['hoverDataList']:  # Looping through hoverDataList
                    Name = z['name']
                    Metric_type = z['metric'][0]['type']
                    count = z['metric'][0]['count']
                    amount = z['metric'][0]['amount']
                    
                    # Appending values
                    clm['State'].append(i)
                    clm['Year'].append(j)
                    clm['Quarter'].append(int(k.strip('.json')))  # removing .json
                    clm['Metric_type'].append(Metric_type)
                    clm['Metric_count'].append(count)
                    clm['Metric_amount'].append(amount)

# Create DataFrame
Map_Insurance = pd.DataFrame(clm)

# Show the DataFrame
print(Map_Insurance)
# Out:
#                            State  Year  Quarter Metric_type  Metric_count  \
# 0      andaman-&-nicobar-islands  2020        2       TOTAL             3
# 1      andaman-&-nicobar-islands  2020        2       TOTAL             3
# 2      andaman-&-nicobar-islands  2020        3       TOTAL             1
# 3      andaman-&-nicobar-islands  2020        3       TOTAL            35
# 4      andaman-&-nicobar-islands  2020        3       TOTAL             5
# ...                          ...   ...      ...         ...           ...
# 13871                west-bengal  2024        4       TOTAL          1023
# 13872                west-bengal  2024        4       TOTAL          4945
# 13873                west-bengal  2024        4       TOTAL          3807
# 13874                west-bengal  2024        4       TOTAL          1818
# 13875                west-bengal  2024        4       TOTAL          3559
#
#        Metric_amount
# 0              795.0
# 1              565.0
# ...

# %%
Map_Insurance
# Out:
#                            State  Year  Quarter Metric_type  Metric_count  \
# 0      andaman-&-nicobar-islands  2020        2       TOTAL             3
# 1      andaman-&-nicobar-islands  2020        2       TOTAL             3
# 2      andaman-&-nicobar-islands  2020        3       TOTAL             1
# 3      andaman-&-nicobar-islands  2020        3       TOTAL            35
# 4      andaman-&-nicobar-islands  2020        3       TOTAL             5
# ...                          ...   ...      ...         ...           ...
# 13871                west-bengal  2024        4       TOTAL          1023
# 13872                west-bengal  2024        4       TOTAL          4945
# 13873                west-bengal  2024        4       TOTAL          3807
# 13874                west-bengal  2024        4       TOTAL          1818
# 13875                west-bengal  2024        4       TOTAL          3559
#
#        Metric_amount
# 0              795.0
# 1              565.0
# ...

# %%
#map Transaction
path="./pulse/data/map/transaction/hover/country/india/state/"
Map_state_list=os.listdir(path)
Map_state_list
clm={'State':[],
     'Year':[],
     'Quarter':[],
     'Metric_type':[],
     'Metric_count':[],
     'Metric_amount':[]}
for i in Map_state_list:
    p_i=path+i+"/"
    Map_yr=os.listdir(p_i) #lists aggregated year 
    for j in Map_yr:
        p_j=p_i+j+"/"
        Map_yr_list=os.listdir(p_j)
        for k in Map_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r') #opening the file in the read only mode
            d=json.load(Data)
            for z in d['data']['hoverDataList']:#Getting into transaction list
                Name=z['name']
                count=z['metric'][0]['count']
                amount=z['metric'][0]['amount']
                #appending details into the clm list
                clm['Metric_type'].append(Name)
                clm['Metric_count'].append(count)
                clm['Metric_amount'].append(amount)
                clm['State'].append(i)
                clm['Year'].append(j)
                clm['Quarter'].append(int(k.strip('.json')))#removes .json 
#dataframe
Map_Trans=pd.DataFrame(clm)

# %%
Map_Trans
# Out:
#                            State  Year  Quarter  \
# 0      andaman-&-nicobar-islands  2018        1
# 1      andaman-&-nicobar-islands  2018        1
# 2      andaman-&-nicobar-islands  2018        1
# 3      andaman-&-nicobar-islands  2018        2
# 4      andaman-&-nicobar-islands  2018        2
# ...                          ...   ...      ...
# 20599                west-bengal  2024        4
# 20600                west-bengal  2024        4
# 20601                west-bengal  2024        4
# 20602                west-bengal  2024        4
# 20603                west-bengal  2024        4
#
#                              Metric_type  Metric_count  Metric_amount
# 0      north and middle andaman district           442   9.316631e+05
# 1                 south andaman district          5688   1.256025e+07
# 2                      nicobars district           528   1.139849e+06
# 3      north and middle andaman district           825   1.317863e+06
# ...

# %%
import os
import json
import pandas as pd

path = "./pulse/data/map/user/hover/country/india/state/"
Map_state_list = os.listdir(path)

clm = {
    'State': [],
    'Year': [],
    'Quarter': [],
    'District': [],
    'RegisteredUsers': [],
    'AppOpens': []
}

for i in Map_state_list:
    p_i = path + i + "/"
    Map_yr = os.listdir(p_i)  # lists aggregated year 
    for j in Map_yr:
        p_j = p_i + j + "/"
        Map_yr_list = os.listdir(p_j)
        for k in Map_yr_list:
            p_k = p_j + k
            with open(p_k, 'r') as Data:  # opening the file in read-only mode
                d = json.load(Data)
                hoverdata = d.get('data', {}).get('hoverData', {})

                for district, values in hoverdata.items():  # Loop over districts/states inside hoverData
                    registered_users = values.get('registeredUsers', 0)
                    app_opens = values.get('appOpens', 0)

                    clm['State'].append(i)
                    clm['Year'].append(j)
                    clm['Quarter'].append(int(k.strip('.json')))
                    clm['District'].append(district)
                    clm['RegisteredUsers'].append(registered_users)
                    clm['AppOpens'].append(app_opens)

# Create DataFrame
Map_user = pd.DataFrame(clm)

# %%
print(p_i)
# Out:
# ./pulse/data/map/user/hover/country/india/state/west-bengal/

# %%
Map_user
# Out:
#                            State  Year  Quarter  \
# 0      andaman-&-nicobar-islands  2018        1
# 1      andaman-&-nicobar-islands  2018        1
# 2      andaman-&-nicobar-islands  2018        1
# 3      andaman-&-nicobar-islands  2018        2
# 4      andaman-&-nicobar-islands  2018        2
# ...                          ...   ...      ...
# 20603                west-bengal  2024        4
# 20604                west-bengal  2024        4
# 20605                west-bengal  2024        4
# 20606                west-bengal  2024        4
# 20607                west-bengal  2024        4
#
#                                 District  RegisteredUsers   AppOpens
# 0      north and middle andaman district              632          0
# 1                 south andaman district             5846          0
# 2                      nicobars district              262          0
# 3      north and middle andaman district              911          0
# ...

# %%
#Top Transaction
path="./pulse/data/top/transaction/country/india/state/"
state_list = os.listdir(path)
clm = {
    'State': [],
    'Year': [],
    'Quarter': [],
    'Level': [],             # State / District / Pincode
    'Metric_type': [],       # Name like Karnataka or Bengaluru Urban
    'Metric_count': [],
    'Metric_amount': []
}

for state in state_list:
    state_path = os.path.join(path, state)
    years = os.listdir(state_path)
    
    for year in years:
        year_path = os.path.join(state_path, year)
        quarters = os.listdir(year_path)
        
        for quarter_file in quarters:
            file_path = os.path.join(year_path, quarter_file)
            quarter = int(quarter_file.strip('.json'))

            with open(file_path, 'r') as f:
                data = json.load(f)

            data_section = data.get('data', {})

            # Extract from each level: states, districts, pincodes
            for level_name in ['states', 'districts', 'pincodes']:
                items = data_section.get(level_name) or []
                for item in items:
                    clm['State'].append(state)
                    clm['Year'].append(year)
                    clm['Quarter'].append(quarter)
                    clm['Level'].append(level_name[:-1].capitalize())  # singular: State/District/Pincode
                    clm['Metric_type'].append(item.get('entityName', 'Unknown'))

                    metric = item.get('metric', {})
                    clm['Metric_count'].append(metric.get('count', 0))
                    clm['Metric_amount'].append(metric.get('amount', 0.0))

# Convert to DataFrame
Top_Trans = pd.DataFrame(clm)

# %%
Top_Trans
# Out:
#                            State  Year  Quarter     Level  \
# 0      andaman-&-nicobar-islands  2018        1  District
# 1      andaman-&-nicobar-islands  2018        1  District
# 2      andaman-&-nicobar-islands  2018        1  District
# 3      andaman-&-nicobar-islands  2018        1   Pincode
# 4      andaman-&-nicobar-islands  2018        1   Pincode
# ...                          ...   ...      ...       ...
# 18290                west-bengal  2024        4   Pincode
# 18291                west-bengal  2024        4   Pincode
# 18292                west-bengal  2024        4   Pincode
# 18293                west-bengal  2024        4   Pincode
# 18294                west-bengal  2024        4   Pincode
#
#                     Metric_type  Metric_count  Metric_amount
# 0                 south andaman          5688   1.256025e+07
# 1                      nicobars           528   1.139849e+06
# 2      north and middle andaman           442   9.316631e+05
# ...

# %%
import os
import json
import pandas as pd

# Path to your user data
path = "./pulse/data/top/user/country/india/state/"

# Check if the path exists
if not os.path.exists(path):
    raise FileNotFoundError(f"The path {path} does not exist!")

state_list = os.listdir(path)
clm = {
    'State': [],
    'Year': [],
    'Quarter': [],
    'Level': [],
    'Metric_type': [],
    'RegisteredUsers': []
}

# Loop through each state folder
for state in state_list:
    state_path = os.path.join(path, state)
    if not os.path.isdir(state_path):
        continue  # Skip if it's not a directory
    
    years = os.listdir(state_path)
    
    for year in years:
        year_path = os.path.join(state_path, year)
        if not os.path.isdir(year_path):
            continue
        
        quarters = os.listdir(year_path)
        
        for quarter_file in quarters:
            file_path = os.path.join(year_path, quarter_file)
            try:
                quarter = int(quarter_file.strip('.json'))
            except ValueError:
                continue  # Skip if the quarter filename is not in the expected format

            try:
                with open(file_path, 'r') as f:
                    data = json.load(f)
            except (IOError, json.JSONDecodeError):
                continue  # Skip files that can't be read or decoded
            
            data_section = data.get('data', {})
            
            # Loop through each level
            for level_name in ['states', 'districts', 'pincodes']:
                items = data_section.get(level_name) or []
                for item in items:
                    clm['State'].append(state)
                    clm['Year'].append(year)
                    clm['Quarter'].append(quarter)
                    clm['Level'].append(level_name[:-1].capitalize())  # Convert plural to singular
                    clm['Metric_type'].append(item.get('name', 'Unknown'))
                    clm['RegisteredUsers'].append(item.get('registeredUsers', 0))

# Convert to DataFrame
Top_Users = pd.DataFrame(clm)

# %%
Top_Users
# Out:
#                            State  Year  Quarter     Level  \
# 0      andaman-&-nicobar-islands  2018        1  District
# 1      andaman-&-nicobar-islands  2018        1  District
# 2      andaman-&-nicobar-islands  2018        1  District
# 3      andaman-&-nicobar-islands  2018        1   Pincode
# 4      andaman-&-nicobar-islands  2018        1   Pincode
# ...                          ...   ...      ...       ...
# 18291                west-bengal  2024        4   Pincode
# 18292                west-bengal  2024        4   Pincode
# 18293                west-bengal  2024        4   Pincode
# 18294                west-bengal  2024        4   Pincode
# 18295                west-bengal  2024        4   Pincode
#
#                     Metric_type  RegisteredUsers
# 0                 south andaman             5846
# 1      north and middle andaman              632
# 2                      nicobars              262
# 3                        744103             1608
# ...

# %%
#top_insurance
path = "./pulse/data/top/insurance/country/india/state/"
state_list = os.listdir(path)

# Initialize columns
clm = {
    'State': [],
    'Year': [],
    'Quarter': [],
    'Level': [],             # State / District / Pincode
    'Metric_type': [],       # Karnataka, Bengaluru Urban, 560001
    'Insurance_count': [],
    'Insurance_amount': []
}

for state in state_list:
    state_path = os.path.join(path, state)
    years = os.listdir(state_path)
    
    for year in years:
        year_path = os.path.join(state_path, year)
        quarters = os.listdir(year_path)
        
        for quarter_file in quarters:
            file_path = os.path.join(year_path, quarter_file)
            quarter = int(quarter_file.strip('.json'))

            with open(file_path, 'r') as f:
                data = json.load(f)

            data_section = data.get('data', {})

            # Loop through each level: states, districts, pincodes
            for level_name in ['states', 'districts', 'pincodes']:
                items = data_section.get(level_name) or []
                for item in items:
                    clm['State'].append(state)
                    clm['Year'].append(year)
                    clm['Quarter'].append(quarter)
                    clm['Level'].append(level_name[:-1].capitalize())
                    clm['Metric_type'].append(item.get('entityName', 'Unknown'))
                    
                    metric = item.get('metric', {})
                    clm['Insurance_count'].append(metric.get('count', 0))
                    clm['Insurance_amount'].append(metric.get('amount', 0.0))

# Convert to DataFrame
top_Insurance = pd.DataFrame(clm)

# %%
top_Insurance
# Out:
#                            State  Year  Quarter     Level    Metric_type  \
# 0      andaman-&-nicobar-islands  2020        2  District       nicobars
# 1      andaman-&-nicobar-islands  2020        2  District  south andaman
# 2      andaman-&-nicobar-islands  2020        2   Pincode         744301
# 3      andaman-&-nicobar-islands  2020        2   Pincode         744104
# 4      andaman-&-nicobar-islands  2020        2   Pincode         744101
# ...                          ...   ...      ...       ...            ...
# 12271                west-bengal  2024        4   Pincode         711101
# 12272                west-bengal  2024        4   Pincode         700091
# 12273                west-bengal  2024        4   Pincode         700150
# 12274                west-bengal  2024        4   Pincode         700039
# 12275                west-bengal  2024        4   Pincode         700156
#
#        Insurance_count  Insurance_amount
# 0                    3             565.0
# ...

# %%
#database

# %%
conn=sqlite3.connect("phonepe_data.sql")
cursor=conn.cursor()

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///phonepe_data.db')

# %%
#Saving dataframes in sql tables
Agg_Trans.to_sql("aggregated_transaction", con=engine, if_exists="replace", index=False)
Agg_Insurance.to_sql("aggregated_insurance", con=engine, if_exists="replace", index=False)
Agg_user.to_sql("aggregated_user", con=engine, if_exists="replace", index=False)
# Out:
# 1008

# %%
from sqlalchemy import inspect

inspector = inspect(engine)
tables = inspector.get_table_names()
print(tables)
# Out:
# ['aggregated_insurance', 'aggregated_transaction', 'aggregated_user']

# %%
# Use PRAGMA to get the table schema in SQLite
columns_query = "PRAGMA table_info(aggregated_user);"
columns = pd.read_sql_query(columns_query, con=engine)

# Display the columns
print(columns)
# Out:
#    cid                   name    type  notnull dflt_value  pk
# 0    0                  State    TEXT        0       None   0
# 1    1                   Year    TEXT        0       None   0
# 2    2                Quarter  BIGINT        0       None   0
# 3    3        Aggregated_type  BIGINT        0       None   0
# 4    4       Aggregated_count  BIGINT        0       None   0
# 5    5  Aggregated_percentage  BIGINT        0       None   0

# %%
from sqlalchemy import create_engine
import pandas as pd

# Create SQLAlchemy engine
engine = sqlite3.connect('phonepe_data.db')
#engine = create_engine('mysql+pymysql://root:Mahesh@localhost/phonepe_data')

# Your SQL Query
query = """
SELECT State, SUM(Aggregated_count) AS Total_Users
FROM aggregated_user
GROUP BY State
ORDER BY Total_Users DESC
"""
result_df = pd.read_sql_query(query, engine)
print(result_df)
# Out:
#                                  State  Total_Users
# 0                          maharashtra  49616423987
# 1                            rajasthan  48507630334
# 2                       madhya-pradesh  39708500796
# 3                            karnataka  38344879267
# 4                        uttar-pradesh  33236833684
# 5                       andhra-pradesh  24728024309
# 6                            telangana  23197773412
# 7                              gujarat  20780416980
# 8                           tamil-nadu  16992199376
# 9                               odisha  14493923288
# 10                               bihar  13608259251
# 11                        chhattisgarh  11190410814
# 12                         west-bengal  10943818827
# 13                           jharkhand  10907909802
# 14                               assam   9436508709
# 15                             haryana   8259126213
# 16                              punjab   5142232156
# ...

# %%
pd.read_sql_query("PRAGMA table_info(aggregated_transaction);", con=engine)
# Out:
#    cid                name    type  notnull dflt_value  pk
# 0    0               State    TEXT        0       None   0
# 1    1                Year    TEXT        0       None   0
# 2    2             Quarter  BIGINT        0       None   0
# 3    3    Transaction_type    TEXT        0       None   0
# 4    4   transaction_count  BIGINT        0       None   0
# 5    5  transaction_amount   FLOAT        0       None   0

# %%
#Aggregated_transaction : Contains aggregated values for map-related data.
#Total Transaction Amount by State
query = """
SELECT State, SUM(transaction_amount) AS Total_Amount
FROM aggregated_transaction
GROUP BY State
ORDER BY Total_Amount;
"""
res_df = pd.read_sql_query(query, engine)
print(res_df)
# Out:
#                                  State  Total_Amount
# 0                          lakshadweep  1.609321e+09
# 1                              mizoram  4.610210e+10
# 2            andaman-&-nicobar-islands  7.066745e+10
# 3                               ladakh  8.899462e+10
# 4                               sikkim  1.189454e+11
# 5                             nagaland  1.303586e+11
# 6                            meghalaya  1.625439e+11
# 7                              manipur  1.862656e+11
# 8                              tripura  2.005834e+11
# 9   dadra-&-nagar-haveli-&-daman-&-diu  2.017199e+11
# 10                          puducherry  2.373171e+11
# 11                   arunachal-pradesh  2.744350e+11
# 12                          chandigarh  2.929066e+11
# 13                                 goa  5.110212e+11
# 14                    himachal-pradesh  6.875374e+11
# 15                     jammu-&-kashmir  1.184683e+12
# 16                         uttarakhand  1.916489e+12
# ...

# %%
#Year wise Transaction Amount
query="""
SELECT Year,Sum(transaction_amount	) AS total_count
FROM aggregated_transaction 
GROUP BY Year
ORDER BY Year;
"""
result_df=pd.read_sql_query(query,engine)
print(result_df)
# Out:
#    Year   total_count
# 0  2018  1.623045e+12
# 1  2019  6.276688e+12
# 2  2020  1.464116e+13
# 3  2021  3.459870e+13
# 4  2022  6.426633e+13
# 5  2023  9.449181e+13
# 6  2024  1.296246e+14

# %%
#Top Transaction by Count
Query="""
SELECT Metric_type, Sum(transaction_count) As Total_Count,
Sum(transaction_amount) As Total_Amount
FROM aggregated_transaction 
GROUP BY Metric_type
ORDER BY Total_Count;
"""
pd.read_sql_query(query,engine)
# Out:
#    Year   total_count
# 0  2018  1.623045e+12
# 1  2019  6.276688e+12
# 2  2020  1.464116e+13
# 3  2021  3.459870e+13
# 4  2022  6.426633e+13
# 5  2023  9.449181e+13
# 6  2024  1.296246e+14

# %%
pd.read_sql_query("PRAGMA table_info (aggregated_insurance);", con=engine)
# Out:
#    cid                name    type  notnull dflt_value  pk
# 0    0               State    TEXT        0       None   0
# 1    1                Year    TEXT        0       None   0
# 2    2             Quarter  BIGINT        0       None   0
# 3    3    Transaction_type    TEXT        0       None   0
# 4    4   transaction_count  BIGINT        0       None   0
# 5    5  transaction_amount   FLOAT        0       None   0

# %%
#Aggregated_insurance: Stores aggregated insurance-related data.
#Total Transaction  Count and Amount by Year
query="""
SELECT Year,SUM(transaction_count) AS Total_Count,
SUM(transaction_amount) As Total_Amount
FROM aggregated_insurance 
GROUP BY Year
ORDER BY Year;
"""
result_df=pd.read_sql_query(query,engine)
print(result_df)
# Out:
#    Year  Total_Count  Total_Amount
# 0  2020       788258  2.942072e+08
# 1  2021      1583282  1.499170e+09
# 2  2022      3090116  4.238843e+09
# 3  2023      3986187  6.056606e+09
# 4  2024      5067844  7.926752e+09

# %%
#Insurance Performance by State
query="""
SELECT State,SUM(transaction_count) AS Total_Count,
SUM(transaction_amount) As Total_Amount
FROM aggregated_insurance 
GROUP BY State
Order BY Total_Amount
"""
result_df=pd.read_sql_query(query,engine)
print(result_df)
# Out:
#                                  State  Total_Count  Total_Amount
# 0                          lakshadweep          496  6.240370e+05
# 1                              mizoram         3724  5.462592e+06
# 2                              manipur         3731  7.150454e+06
# 3                               ladakh         3338  7.808333e+06
# 4                             nagaland         4745  9.156617e+06
# 5                               sikkim         4896  1.088338e+07
# 6   dadra-&-nagar-haveli-&-daman-&-diu        13792  1.799241e+07
# 7            andaman-&-nicobar-islands        12997  1.938679e+07
# 8                            meghalaya        10461  2.035736e+07
# 9                    arunachal-pradesh        10214  2.342076e+07
# 10                          chandigarh        22079  3.328588e+07
# 11                             tripura        25192  3.374246e+07
# 12                          puducherry        27940  3.712085e+07
# ...

# %%
#Quarterly Insurance Overview
Query="""
SELECT Quarter,SUM(transaction_count) AS Total_Count, 
SUM(transaction_amount) AS Total_Amount
FROM aggregated_insurance 
ORDER BY Quarter
GROUP BY Quarter
"""
result_df=pd.read_sql_query(query,engine)
print(result_df)
# Out:
#                                  State  Total_Count  Total_Amount
# 0                          lakshadweep          496  6.240370e+05
# 1                              mizoram         3724  5.462592e+06
# 2                              manipur         3731  7.150454e+06
# 3                               ladakh         3338  7.808333e+06
# 4                             nagaland         4745  9.156617e+06
# 5                               sikkim         4896  1.088338e+07
# 6   dadra-&-nagar-haveli-&-daman-&-diu        13792  1.799241e+07
# 7            andaman-&-nicobar-islands        12997  1.938679e+07
# 8                            meghalaya        10461  2.035736e+07
# 9                    arunachal-pradesh        10214  2.342076e+07
# 10                          chandigarh        22079  3.328588e+07
# 11                             tripura        25192  3.374246e+07
# 12                          puducherry        27940  3.712085e+07
# ...

# %%
#Saving dataframes in sql tables
Map_Trans.to_sql("map_transaction", con=engine, if_exists="replace", index=False)
Map_Insurance.to_sql("map_insurance", con=engine, if_exists="replace", index=False)
Map_user.to_sql("map_user", con=engine, if_exists="replace", index=False)
# Out:
# 20608

# %%
pd.read_sql_query("PRAGMA table_info (map_user);", con=engine)
# Out:
#    cid             name     type  notnull dflt_value  pk
# 0    0            State     TEXT        0       None   0
# 1    1             Year     TEXT        0       None   0
# 2    2          Quarter  INTEGER        0       None   0
# 3    3         District     TEXT        0       None   0
# 4    4  RegisteredUsers  INTEGER        0       None   0
# 5    5         AppOpens  INTEGER        0       None   0

# %%
#Map_user: Contains mapping information for users.
#Total Registered Users by State
query = """
SELECT State, SUM(RegisteredUsers) AS Total_Registered_Users
FROM map_user
GROUP BY State
ORDER BY Total_Registered_Users DESC;
"""

result = pd.read_sql_query(query, engine)
print(result)
# Out:
#                                  State  Total_Registered_Users
# 0                          maharashtra              1140138243
# 1                        uttar-pradesh               942334146
# 2                            karnataka               733674236
# 3                       andhra-pradesh               556747126
# 4                            rajasthan               555774493
# 5                          west-bengal               524964358
# 6                            telangana               524620520
# 7                           tamil-nadu               506486772
# 8                       madhya-pradesh               470663624
# 9                              gujarat               459154666
# 10                               bihar               446115282
# 11                               delhi               324608095
# 12                             haryana               306022101
# 13                              odisha               290005345
# ...

# %%
#Total Registered Users by Year
# SQL query to get the total registered users by year
query = """
SELECT Year, SUM(RegisteredUsers) AS Total_Users
FROM map_user
GROUP BY Year
ORDER BY Year;
"""

# Execute the query and load the result into a pandas DataFrame
result_df = pd.read_sql_query(query, con=engine)

# Display the result
print(result_df)
# Out:
#    Year  Total_Users
# 0  2018    292797872
# 1  2019    602811578
# 2  2020    922009385
# 3  2021   1269755730
# 4  2022   1614644108
# 5  2023   1927042597
# 6  2024   2235135588

# %%
#Top Districts by App Opens
query = """
SELECT District, SUM(AppOpens) AS TotalAppOpens
FROM map_user
GROUP BY District
ORDER BY TotalAppOpens DESC
LIMIT 10;
"""
# Execute the query and load the result into a pandas DataFrame
result_df = pd.read_sql_query(query, con=engine)

# Display the result
print(result_df)
# Out:
#                    District  TotalAppOpens
# 0  bengaluru urban district     8626628836
# 1             pune district     6244893293
# 2       ganganagar district     4524201942
# 3           barmer district     3492607573
# 4           nashik district     3388420299
# 5           jaipur district     3207851308
# 6      hanumangarh district     3202109331
# 7          bikaner district     3132601151
# 8       rangareddy district     3037773260
# 9          jodhpur district     2981713844

# %%
pd.read_sql_query("PRAGMA table_info (map_insurance);", con=engine)
# Out:
#    cid           name     type  notnull dflt_value  pk
# 0    0          State     TEXT        0       None   0
# 1    1           Year     TEXT        0       None   0
# 2    2        Quarter  INTEGER        0       None   0
# 3    3    Metric_type     TEXT        0       None   0
# 4    4   Metric_count  INTEGER        0       None   0
# 5    5  Metric_amount     REAL        0       None   0

# %%
#Map_insurance: Includes mapping information related to insurance.
# Getting metric count,amount by state,metric type
query = """
SELECT State, Metric_type AS Type,
       SUM(Metric_count) AS Total_Count,
       SUM(Metric_amount) AS Total_Amount
FROM map_insurance
GROUP BY State, Metric_type
"""
result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#                                  State   Type  Total_Count  Total_Amount
# 0            andaman-&-nicobar-islands  TOTAL        12997  1.938679e+07
# 1                       andhra-pradesh  TOTAL       697769  8.122230e+08
# 2                    arunachal-pradesh  TOTAL        10214  2.342076e+07
# 3                                assam  TOTAL       262818  4.118310e+08
# 4                                bihar  TOTAL       536592  6.710568e+08
# 5                           chandigarh  TOTAL        22079  3.328588e+07
# 6                         chhattisgarh  TOTAL       189517  2.743449e+08
# 7   dadra-&-nagar-haveli-&-daman-&-diu  TOTAL        13792  1.799241e+07
# 8                                delhi  TOTAL       652514  8.153652e+08
# 9                                  goa  TOTAL        59872  8.373000e+07
# 10                             gujarat  TOTAL       562595  7.292334e+08
# 11                             haryana  TOTAL       573738  8.309812e+08
# ...

# %%
# Getting metric count,amount by year,metric type
query = """
SELECT Year, Metric_type AS Type,
       SUM(Metric_count) AS Total_Count,
       SUM(Metric_amount) AS Total_Amount
FROM map_insurance
GROUP BY Year, Metric_type
"""
result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#    Year   Type  Total_Count  Total_Amount
# 0  2020  TOTAL       788258  2.942072e+08
# 1  2021  TOTAL      1583282  1.499170e+09
# 2  2022  TOTAL      3090116  4.238843e+09
# 3  2023  TOTAL      3986187  6.056606e+09
# 4  2024  TOTAL      5067844  7.926752e+09

# %%
# Getting metric count,amount by Quarter, metric type
query = """
SELECT Quarter, Metric_type AS Type,
       SUM(Metric_count) AS Total_Count,
       SUM(Metric_amount) AS Total_Amount
FROM map_insurance
GROUP BY Quarter, Metric_type
ORDER BY Quarter
"""
result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#    Quarter   Type  Total_Count  Total_Amount
# 0        1  TOTAL      3132598  4.434409e+09
# 1        2  TOTAL      3178914  4.292770e+09
# 2        3  TOTAL      3759419  4.873032e+09
# 3        4  TOTAL      4444756  6.415368e+09

# %%
pd.read_sql_query("PRAGMA table_info (map_transaction);", con=engine)
# Out:
#    cid           name     type  notnull dflt_value  pk
# 0    0          State     TEXT        0       None   0
# 1    1           Year     TEXT        0       None   0
# 2    2        Quarter  INTEGER        0       None   0
# 3    3    Metric_type     TEXT        0       None   0
# 4    4   Metric_count  INTEGER        0       None   0
# 5    5  Metric_amount     REAL        0       None   0

# %%
# To list all tables
tables = pd.read_sql_query("SHOW TABLES;", con=engine)
print(tables)
# Out:
#    Tables_in_phonepe_data
# 0    aggregated_insurance
# 1  aggregated_transaction
# 2         aggregated_user
# 3           map_insurance
# 4         map_transaction
# 5                map_user
# 6           top_insurance
# 7         top_transaction
# 8                top_user

# %%
#Map_insurance: Includes mapping information related to insurance.
# Getting metric count,amount by state,metric type
query = """
SELECT State, Metric_type AS Type,
       SUM(Metric_count) AS Total_Count,
       SUM(Metric_amount) AS Total_Amount
FROM map_transaction
GROUP BY State, Metric_type
"""
result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#                          State                                 Type  \
# 0    andaman-&-nicobar-islands                     nicobar district
# 1    andaman-&-nicobar-islands                    nicobars district
# 2    andaman-&-nicobar-islands    north and middle andaman district
# 3    andaman-&-nicobar-islands               south andaman district
# 4               andhra-pradesh       alluri sitharama raju district
# ..                         ...                                  ...
# 847                west-bengal             purba bardhaman district
# 848                west-bengal             purba medinipur district
# 849                west-bengal                     purulia district
# 850                west-bengal  south twenty four parganas district
# 851                west-bengal              uttar dinajpur district
#
#      Total_Count  Total_Amount
# 0         443356  7.741392e+08
# 1        1124902  2.522901e+09
# 2        2671727  6.101007e+09
# ...

# %%
# Getting metric count,amount by Year,metric type
query = """
SELECT Year, Metric_type AS Type,
       SUM(Metric_count) AS Total_Count,
       SUM(Metric_amount) AS Total_Amount
FROM map_transaction
GROUP BY Year, Metric_type
"""
result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#       Year                  Type  Total_Count  Total_Amount
# 0     2018     adilabad district       291415  5.579849e+08
# 1     2018   agar malwa district       301408  7.334309e+08
# 2     2018         agra district      1897667  3.325728e+09
# 3     2018    ahmadabad district      9836304  1.671689e+10
# 4     2018   ahmednagar district      3124695  5.322993e+09
# ...    ...                   ...          ...           ...
# 5176  2024  yamunanagar district     36915981  5.375703e+10
# 5177  2024        yanam district      7064421  9.997911e+09
# 5178  2024     yavatmal district    151768167  1.956114e+11
# 5179  2024          ysr district    366318734  6.925374e+11
# 5180  2024    zunheboto district       383923  8.319153e+08
#
# [5181 rows x 4 columns]

# %%
# Getting metric count,amount by Quarter,metric type
query = """
SELECT Quarter, Metric_type AS Type,
       SUM(Metric_count) AS Total_Count,
       SUM(Metric_amount) AS Total_Amount
FROM map_transaction
GROUP BY Quarter, Metric_type
"""
result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#       Quarter                  Type  Total_Count  Total_Amount
# 0           1     adilabad district     29809498  5.429301e+10
# 1           1   agar malwa district     20207769  3.061281e+10
# 2           1         agra district    109530027  1.776838e+11
# 3           1    ahmadabad district    370835118  6.048061e+11
# 4           1   ahmednagar district    263313654  4.180782e+11
# ...       ...                   ...          ...           ...
# 3127        4  yamunanagar district     24822548  4.243725e+10
# 3128        4        yanam district      4482873  6.937665e+09
# 3129        4     yavatmal district     95331747  1.304334e+11
# 3130        4          ysr district    255207285  5.442400e+11
# 3131        4    zunheboto district       289434  7.329972e+08
#
# [3132 rows x 4 columns]

# %%
#Saving dataframes in sql tables
Top_Trans.to_sql("top_transaction", con=engine, if_exists="replace", index=False)
top_Insurance.to_sql("top_insurance", con=engine, if_exists="replace", index=False)
Top_Users.to_sql("top_user", con=engine, if_exists="replace", index=False)
# Out:
# 18296

# %%
pd.read_sql_query("PRAGMA table_info (top_user);", con=engine)
# Out:
#    cid             name     type  notnull dflt_value  pk
# 0    0            State     TEXT        0       None   0
# 1    1             Year     TEXT        0       None   0
# 2    2          Quarter  INTEGER        0       None   0
# 3    3            Level     TEXT        0       None   0
# 4    4      Metric_type     TEXT        0       None   0
# 5    5  RegisteredUsers  INTEGER        0       None   0

# %%
# Total Registered Users by State
query = """
SELECT State, SUM(RegisteredUsers) AS Total_Registered_Users
FROM top_user
GROUP BY State;
"""
result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#                                  State  Total_Registered_Users
# 0            andaman-&-nicobar-islands                 3437980
# 1                       andhra-pradesh               504044931
# 2                    arunachal-pradesh                11141709
# 3                                assam                74134441
# 4                                bihar               263623407
# 5                           chandigarh                22724135
# 6                         chhattisgarh               131032229
# 7   dadra-&-nagar-haveli-&-daman-&-diu                20159102
# 8                                delhi               397748721
# 9                                  goa                24839707
# 10                             gujarat               377455263
# 11                             haryana               282541590
# 12                    himachal-pradesh                60837613
# 13                     jammu-&-kashmir                38072658
# ...

# %%
#Year-wise Registrations
query = """
SELECT Year, SUM(RegisteredUsers) AS Total_Registered_Users
FROM top_user
GROUP BY Year;
"""
result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#    Year  Total_Registered_Users
# 0  2018               244556782
# 1  2019               494276489
# 2  2020               730807790
# 3  2021               992455317
# 4  2022              1255453987
# 5  2023              1494541989
# 6  2024              1669810521

# %%
#Quarter-wise Registration
query = """
SELECT Quarter, SUM(RegisteredUsers) AS Total_Registered_Users
FROM top_user
GROUP BY Quarter;
"""
result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#    Quarter  Total_Registered_Users
# 0        1              1577307067
# 1        2              1680707069
# 2        3              1757501148
# 3        4              1866387591

# %%
pd.read_sql_query("PRAGMA table_info (top_transaction);", con=engine)
# Out:
#    cid           name     type  notnull dflt_value  pk
# 0    0          State     TEXT        0       None   0
# 1    1           Year     TEXT        0       None   0
# 2    2        Quarter  INTEGER        0       None   0
# 3    3          Level     TEXT        0       None   0
# 4    4    Metric_type     TEXT        0       None   0
# 5    5   Metric_count  INTEGER        0       None   0
# 6    6  Metric_amount     REAL        0       None   0

# %%
#Top_transaction: Contains totals for the top states, districts, and pin codes.
#Top 10 Pincodes by Transaction Amount
query="""
SELECT Metric_type AS Pincode, SUM(Metric_amount) AS Total_Amount
FROM top_transaction
WHERE Level = 'Pincode'
GROUP BY Metric_type
ORDER BY Total_Amount DESC
LIMIT 10;
"""
result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#   Pincode  Total_Amount
# 0  500001  2.930982e+12
# 1  500034  2.777747e+12
# 2  560001  2.151967e+12
# 3  110006  1.890727e+12
# 4  411004  1.800762e+12
# 5  302016  1.528114e+12
# 6  800001  1.500670e+12
# 7  302012  1.165971e+12
# 8  462008  1.052087e+12
# 9  500072  1.026144e+12

# %%
#Top 10  Districts by Transaction Count
query="""
SELECT Metric_type AS District, SUM(Metric_amount) AS Total_Amount
FROM top_transaction
WHERE Level = 'District'
GROUP BY Metric_type
ORDER BY Total_Amount DESC
LIMIT 10;
"""
result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#              District  Total_Amount
# 0     bengaluru urban  1.993784e+13
# 1           hyderabad  1.190694e+13
# 2                pune  9.730218e+12
# 3              jaipur  7.854092e+12
# 4          rangareddy  7.155140e+12
# 5  medchal malkajgiri  5.758878e+12
# 6       visakhapatnam  4.198568e+12
# 7              guntur  3.174527e+12
# 8               patna  3.110762e+12
# 9             khordha  2.992147e+12

# %%
pd.read_sql_query("PRAGMA table_info (top_insurance);", con=engine)
# Out:
#    cid              name     type  notnull dflt_value  pk
# 0    0             State     TEXT        0       None   0
# 1    1              Year     TEXT        0       None   0
# 2    2           Quarter  INTEGER        0       None   0
# 3    3             Level     TEXT        0       None   0
# 4    4       Metric_type     TEXT        0       None   0
# 5    5   Insurance_count  INTEGER        0       None   0
# 6    6  Insurance_amount     REAL        0       None   0

# %%
#Top_Users
pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table';", con=engine)
print(tables)
# Out:
# ['aggregated_insurance', 'aggregated_transaction', 'aggregated_user']

# %%
#Top_insurance: Lists totals for the top insurance categories.
#total count of insurance policies sold across all states, years, and quarters
query = """
SELECT State, SUM(Insurance_count) AS Total_Insurance_Sold
FROM top_insurance
GROUP BY State
ORDER BY Total_Insurance_Sold DESC;
"""
result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#                                  State  Total_Insurance_Sold
# 0                            karnataka               1898067
# 1                          maharashtra               1603208
# 2                           tamil-nadu               1018072
# 3                            telangana                912222
# 4                                delhi                803519
# 5                               kerala                781514
# 6                        uttar-pradesh                766825
# 7                          west-bengal                720687
# 8                       andhra-pradesh                679302
# 9                              haryana                605097
# 10                             gujarat                536722
# 11                           rajasthan                517676
# 12                               bihar                392051
# 13                      madhya-pradesh                366861
# ...

# %%
#total count of insurance policies sold across all  years
query = """
SELECT Year, SUM(Insurance_count) AS Total_Insurance_Sold
FROM top_insurance
GROUP BY Year
ORDER BY Total_Insurance_Sold;
"""
result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#    Year  Total_Insurance_Sold
# 0  2020                743865
# 1  2021               1437046
# 2  2022               2891729
# 3  2023               3775874
# 4  2024               4540796

# %%
#total count of insurance policies sold across all  quarters
query = """
SELECT Quarter, SUM(Insurance_count) AS Total_Insurance_Sold
FROM top_insurance
GROUP BY Quarter
ORDER BY Total_Insurance_Sold;
"""
result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#    Quarter  Total_Insurance_Sold
# 0        1               2878752
# 1        2               2964079
# 2        3               3483704
# 3        4               4062775

# %%
query = "SELECT name FROM sqlite_master WHERE type='table';"
tables = pd.read_sql_query(query, con=engine)
print(tables)
# Out:
#                      name
# 0  aggregated_transaction
# 1    aggregated_insurance
# 2         aggregated_user
# 3         map_transaction
# 4           map_insurance
# 5                map_user
# 6         top_transaction
# 7           top_insurance
# 8                top_user

# %%
#CASE STUDY
#1. Decoding Transaction Dynamics on PhonePe
#AGGRGATED_TRANSACTION
#Total Transactions and Amount by State
import pandas as pd
query="""
SELECT state, SUM(transaction_count) AS total_transactions, SUM(transaction_amount) AS total_amount
FROM aggregated_transaction
GROUP BY state
ORDER BY total_amount DESC;
"""
result_df=pd.read_sql_query(query,con=engine)
print(result_df)
# Out:
#                                  State  total_transactions  total_amount
# 0                            telangana         26174684592  4.165596e+13
# 1                            karnataka         30970946279  4.067872e+13
# 2                          maharashtra         31985208732  4.037420e+13
# 3                       andhra-pradesh         18918696723  3.466908e+13
# 4                        uttar-pradesh         18523603727  2.688521e+13
# 5                            rajasthan         17108537898  2.634324e+13
# 6                       madhya-pradesh         14072176059  1.912528e+13
# 7                                bihar         10941026824  1.790135e+13
# 8                          west-bengal          9191499687  1.558416e+13
# 9                               odisha          8918527452  1.226398e+13
# 10                          tamil-nadu          7796386037  1.193622e+13
# 11                               delhi          8495316647  1.163752e+13
# ...

# %%
#Transaction Trends by Year and Quarter
query="""
SELECT year, quarter, SUM(transaction_amount) AS total_amount
FROM aggregated_transaction
GROUP BY year, quarter
ORDER BY year, quarter;
"""
result_df=pd.read_sql_query(query,con=engine)
print(result_df)
# Out:
#     Year  Quarter  total_amount
# 0   2018        1  1.718334e+11
# 1   2018        2  3.043742e+11
# 2   2018        3  4.751015e+11
# 3   2018        4  6.717362e+11
# 4   2019        1  9.900214e+11
# 5   2019        2  1.354214e+12
# 6   2019        3  1.672559e+12
# 7   2019        4  2.259894e+12
# 8   2020        1  2.697112e+12
# 9   2020        2  2.646145e+12
# 10  2020        3  3.902053e+12
# 11  2020        4  5.395851e+12
# 12  2021        1  6.284243e+12
# 13  2021        2  7.476466e+12
# 14  2021        3  9.216696e+12
# 15  2021        4  1.162129e+13
# 16  2022        1  1.323963e+13
# 17  2022        2  1.550419e+13
# 18  2022        3  1.660763e+13
# 19  2022        4  1.891489e+13
# 20  2023        1  2.051396e+13
# 21  2023        2  2.291849e+13
# 22  2023        3  2.401213e+13
# 23  2023        4  2.704723e+13
# 24  2024        1  2.945843e+13
# 25  2024        2  3.182035e+13
# 26  2024        3  3.234697e+13
# 27  2024        4  3.599880e+13

# %%
#Payment Category Analysis
query="""
SELECT Transaction_type, 
       SUM(transaction_count) AS total_transactions, 
       SUM(transaction_amount) AS total_amount
FROM aggregated_transaction
GROUP BY Transaction_type
ORDER BY total_amount DESC;
"""
result_df=pd.read_sql_query(query,con=engine)
print(result_df)
# Out:
#            Transaction_type  total_transactions  total_amount
# 0     Peer-to-peer payments         85032446653  2.665274e+14
# 1         Merchant payments        130238755487  6.533988e+13
# 2  Recharge & bill payments         19596755603  1.333876e+13
# 3                    Others           262050188  1.742807e+11
# 4        Financial Services           154208943  1.420188e+11

# %%
#MAP_TRANSACTION
#Total Transaction Amount by State
query = """
SELECT State, Metric_type, SUM(Metric_amount) AS total_amount
FROM map_transaction
GROUP BY State, Metric_type
ORDER BY total_amount DESC;
"""

result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#            State               Metric_type  total_amount
# 0      karnataka  bengaluru urban district  1.993784e+13
# 1      telangana        hyderabad district  1.190694e+13
# 2    maharashtra             pune district  9.730218e+12
# 3      rajasthan           jaipur district  7.854092e+12
# 4      telangana       rangareddy district  7.155140e+12
# ..           ...                       ...           ...
# 847     nagaland         shamator district  8.547220e+07
# 848      mizoram        hnahthial district  7.425357e+07
# 849      mizoram         khawzawl district  5.998474e+07
# 850     nagaland         tseminyu district  5.325309e+07
# 851     nagaland          niuland district  2.744951e+06
#
# [852 rows x 3 columns]

# %%
query = "PRAGMA table_info(map_transaction);"
table_structure = pd.read_sql_query(query, con=engine)
print(table_structure)
# Out:
#    cid           name     type  notnull dflt_value  pk
# 0    0          State     TEXT        0       None   0
# 1    1           Year     TEXT        0       None   0
# 2    2        Quarter  INTEGER        0       None   0
# 3    3    Metric_type     TEXT        0       None   0
# 4    4   Metric_count  INTEGER        0       None   0
# 5    5  Metric_amount     REAL        0       None   0

# %%
#District-Wise Growth (Over Quarters)
#Total Transaction Amount by District
query = """
SELECT state, year, quarter, SUM(metric_amount) AS total_amount
FROM map_transaction
GROUP BY state, year, quarter
ORDER BY state, year, quarter;
"""

result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#                           State  Year  Quarter  total_amount
# 0     andaman-&-nicobar-islands  2018        1  1.463176e+07
# 1     andaman-&-nicobar-islands  2018        2  2.833854e+07
# 2     andaman-&-nicobar-islands  2018        3  5.555747e+07
# 3     andaman-&-nicobar-islands  2018        4  9.054834e+07
# 4     andaman-&-nicobar-islands  2019        1  1.022997e+08
# ...                         ...   ...      ...           ...
# 1003                west-bengal  2023        4  1.249395e+12
# 1004                west-bengal  2024        1  1.422026e+12
# 1005                west-bengal  2024        2  1.547344e+12
# 1006                west-bengal  2024        3  1.607644e+12
# 1007                west-bengal  2024        4  1.810100e+12
#
# [1008 rows x 4 columns]

# %%
pd.read_sql_query("PRAGMA table_info(top_transaction);", con=engine)
# Out:
#    cid           name     type  notnull dflt_value  pk
# 0    0          State     TEXT        0       None   0
# 1    1           Year     TEXT        0       None   0
# 2    2        Quarter  INTEGER        0       None   0
# 3    3          Level     TEXT        0       None   0
# 4    4    Metric_type     TEXT        0       None   0
# 5    5   Metric_count  INTEGER        0       None   0
# 6    6  Metric_amount     REAL        0       None   0

# %%
#Top Pincodes by Transaction Amount
query = """
SELECT Metric_type AS Pincode, SUM(Metric_amount) AS Total_Transaction_Amount
FROM top_transaction
WHERE Level = 'Pincode'
GROUP BY Metric_type
ORDER BY Total_Transaction_Amount DESC
LIMIT 10;
"""

result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#   Pincode  Total_Transaction_Amount
# 0  500001              2.930982e+12
# 1  500034              2.777747e+12
# 2  560001              2.151967e+12
# 3  110006              1.890727e+12
# 4  411004              1.800762e+12
# 5  302016              1.528114e+12
# 6  800001              1.500670e+12
# 7  302012              1.165971e+12
# 8  462008              1.052087e+12
# 9  500072              1.026144e+12

# %%
#Quarterly Pincode Transaction Growth
query = """
SELECT State,Metric_type AS Pincode,Year,Quarter, SUM(Metric_amount) AS Total_Transaction_Amount
FROM top_transaction
WHERE Level = 'Pincode'
GROUP BY Metric_type,State,Year,Quarter
ORDER BY Total_Transaction_Amount DESC
LIMIT 10;
"""

result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#          State Pincode  Year  Quarter  Total_Transaction_Amount
# 0    telangana  500034  2022        4              1.501500e+12
# 1    telangana  500034  2022        3              1.276247e+12
# 2    telangana  500001  2022        2              5.366590e+11
# 3    telangana  500001  2022        1              4.609488e+11
# 4    rajasthan  302012  2022        4              4.014471e+11
# 5    telangana  500001  2021        4              3.987981e+11
# 6    karnataka  560027  2022        4              3.839804e+11
# 7    karnataka  560001  2022        2              3.670115e+11
# 8  maharashtra  411004  2022        2              3.564370e+11
# 9        delhi  110006  2022        4              3.494872e+11

# %%
#2.Device Dominance and User Engagement Analysis Scenario
#Total Registered Users and App Opens by District ,Year
query = """
SELECT 
    District, 
    Year,
    SUM(RegisteredUsers) AS total_registered_users,
    SUM(AppOpens) AS total_app_opens
FROM 
    map_user
GROUP BY 
    District, Year
ORDER BY 
    total_registered_users DESC;
"""

# Execute the query and fetch the result
result_df = pd.read_sql_query(query, con=engine)

# Print the result
print(result_df)
# Out:
#                       District  Year  total_registered_users  total_app_opens
# 0     bengaluru urban district  2024                71301822       1679021307
# 1     bengaluru urban district  2023                64380514       1242692313
# 2     bengaluru urban district  2022                54702637       1532960489
# 3                pune district  2024                48637740       1589030102
# 4     bengaluru urban district  2021                43919783       2097371327
# ...                        ...   ...                     ...              ...
# 5176    pakke kessang district  2018                     346                0
# 5177     muzaffarabad district  2018                     323                0
# 5178            kamle district  2018                     233                0
# 5179         pherzawl district  2018                     181                0
# 5180          niuland district  2024                      85              178
#
# [5181 rows x 4 columns]

# %%
#Top Users by Registered Users
query = """
SELECT 
    State,
    Year,
    Quarter,
    SUM(RegisteredUsers) AS Total_Registered_Users
FROM 
    top_user
GROUP BY 
    State, Year, Quarter
ORDER BY 
    Total_Registered_Users DESC
"""

# Execute the query and fetch the result
result_df = pd.read_sql_query(query, con=engine)

# Print the result
print(result_df)
# Out:
#             State  Year  Quarter  Total_Registered_Users
# 0     maharashtra  2024        4                52137276
# 1     maharashtra  2024        2                51821863
# 2     maharashtra  2024        3                50656958
# 3     maharashtra  2024        1                49944032
# 4     maharashtra  2023        4                48092872
# ...           ...   ...      ...                     ...
# 1003  lakshadweep  2019        1                    2832
# 1004  lakshadweep  2018        4                    2312
# 1005  lakshadweep  2018        3                    1836
# 1006  lakshadweep  2018        2                    1372
# 1007  lakshadweep  2018        1                    1002
#
# [1008 rows x 4 columns]

# %%
query = "PRAGMA table_info(aggregated_user);"
table_structure = pd.read_sql_query(query, con=engine)
print(table_structure)
# Out:
#    cid                   name    type  notnull dflt_value  pk
# 0    0                  State    TEXT        0       None   0
# 1    1                   Year    TEXT        0       None   0
# 2    2                Quarter  BIGINT        0       None   0
# 3    3        Aggregated_type  BIGINT        0       None   0
# 4    4       Aggregated_count  BIGINT        0       None   0
# 5    5  Aggregated_percentage  BIGINT        0       None   0

# %%
query = "PRAGMA table_info (map_user);"
table_structure = pd.read_sql_query(query, con=engine)
print(table_structure)
# Out:
#    cid             name     type  notnull dflt_value  pk
# 0    0            State     TEXT        0       None   0
# 1    1             Year     TEXT        0       None   0
# 2    2          Quarter  INTEGER        0       None   0
# 3    3         District     TEXT        0       None   0
# 4    4  RegisteredUsers  INTEGER        0       None   0
# 5    5         AppOpens  INTEGER        0       None   0

# %%
query = "PRAGMA table_info (top_user);"
table_structure = pd.read_sql_query(query, con=engine)
print(table_structure)
# Out:
#    cid             name     type  notnull dflt_value  pk
# 0    0            State     TEXT        0       None   0
# 1    1             Year     TEXT        0       None   0
# 2    2          Quarter  INTEGER        0       None   0
# 3    3            Level     TEXT        0       None   0
# 4    4      Metric_type     TEXT        0       None   0
# 5    5  RegisteredUsers  INTEGER        0       None   0

# %%
#3. Insurance Penetration and Growth Potential Analysis
query = """
SELECT 
    ai.state,
    SUM(ai.transaction_amount) AS total_insurance_premium,
    COUNT(DISTINCT ai.transaction_type) AS total_transaction_types,
    SUM(at.transaction_amount) AS total_transaction_amount,
    COUNT(DISTINCT at.transaction_type) AS total_transactions
FROM 
    aggregated_insurance ai
JOIN 
    aggregated_transaction at
    ON ai.state = at.state  -- Assuming there is a relationship between state in both tables
WHERE 
    ai.transaction_amount > 0
GROUP BY 
    ai.state
ORDER BY 
    total_insurance_premium DESC;
"""

result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#                                  State  total_insurance_premium  \
# 0                            karnataka             3.840417e+11
# 1                          maharashtra             3.308380e+11
# 2                        uttar-pradesh             2.436485e+11
# 3                           tamil-nadu             2.177710e+11
# 4                               kerala             1.839206e+11
# 5                            telangana             1.639483e+11
# 6                          west-bengal             1.473449e+11
# 7                            rajasthan             1.343515e+11
# 8                              haryana             1.163374e+11
# 9                                delhi             1.141511e+11
# 10                      andhra-pradesh             1.137112e+11
# 11                             gujarat             1.020927e+11
# 12                      madhya-pradesh             9.956149e+10
# 13                               bihar             9.394795e+10
# ...

# %%
query = "PRAGMA table_info (aggregated_insurance);"
table_structure = pd.read_sql_query(query, con=engine)
print(table_structure)
# Out:
#    cid                name    type  notnull dflt_value  pk
# 0    0               State    TEXT        0       None   0
# 1    1                Year    TEXT        0       None   0
# 2    2             Quarter  BIGINT        0       None   0
# 3    3    Transaction_type    TEXT        0       None   0
# 4    4   transaction_count  BIGINT        0       None   0
# 5    5  transaction_amount   FLOAT        0       None   0

# %%
#4.Transaction Analysis for Market Expansion
#Transaction Volume and Value by State:
query = """
SELECT 
    state,
    SUM(transaction_amount) AS total_transaction_value,
    COUNT(*) AS total_transactions
FROM 
    aggregated_transaction
GROUP BY 
    state
ORDER BY 
    total_transaction_value DESC;

"""

result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#                                  State  total_transaction_value  \
# 0                            telangana             4.165596e+13
# 1                            karnataka             4.067872e+13
# 2                          maharashtra             4.037420e+13
# 3                       andhra-pradesh             3.466908e+13
# 4                        uttar-pradesh             2.688521e+13
# 5                            rajasthan             2.634324e+13
# 6                       madhya-pradesh             1.912528e+13
# 7                                bihar             1.790135e+13
# 8                          west-bengal             1.558416e+13
# 9                               odisha             1.226398e+13
# 10                          tamil-nadu             1.193622e+13
# 11                               delhi             1.163752e+13
# 12                             gujarat             1.019291e+13
# 13                             haryana             9.645037e+12
# ...

# %%
#User Growth in Each State:
query = """
SELECT 
    State,
    SUM(RegisteredUsers) AS total_users
FROM 
    map_user
GROUP BY 
    State
ORDER BY 
    total_users DESC;
"""

result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#                                  State  total_users
# 0                          maharashtra   1140138243
# 1                        uttar-pradesh    942334146
# 2                            karnataka    733674236
# 3                       andhra-pradesh    556747126
# 4                            rajasthan    555774493
# 5                          west-bengal    524964358
# 6                            telangana    524620520
# 7                           tamil-nadu    506486772
# 8                       madhya-pradesh    470663624
# 9                              gujarat    459154666
# 10                               bihar    446115282
# 11                               delhi    324608095
# 12                             haryana    306022101
# 13                              odisha    290005345
# 14                              kerala    204758075
# 15                              punjab    171432251
# 16                           jharkhand    169283936
# ...

# %%
query = "PRAGMA table_info (aggregated_user);"
table_structure = pd.read_sql_query(query, con=engine)
print(table_structure)
# Out:
#    cid                   name    type  notnull dflt_value  pk
# 0    0                  State    TEXT        0       None   0
# 1    1                   Year    TEXT        0       None   0
# 2    2                Quarter  BIGINT        0       None   0
# 3    3        Aggregated_type  BIGINT        0       None   0
# 4    4       Aggregated_count  BIGINT        0       None   0
# 5    5  Aggregated_percentage  BIGINT        0       None   0

# %%
query = "PRAGMA table_info (map_user);"
table_structure = pd.read_sql_query(query, con=engine)
print(table_structure)
# Out:
#    cid             name     type  notnull dflt_value  pk
# 0    0            State     TEXT        0       None   0
# 1    1             Year     TEXT        0       None   0
# 2    2          Quarter  INTEGER        0       None   0
# 3    3         District     TEXT        0       None   0
# 4    4  RegisteredUsers  INTEGER        0       None   0
# 5    5         AppOpens  INTEGER        0       None   0

# %%
#Insurance Market Penetration by Region
query = """
SELECT 
    state,
    SUM(transaction_amount) AS total_insurance_premium,
    COUNT(*) AS total_insurance_transactions
FROM 
    aggregated_insurance
GROUP BY 
    state
ORDER BY 
    total_insurance_premium DESC;

"""

result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#                                  State  total_insurance_premium  \
# 0                            karnataka             2.743155e+09
# 1                          maharashtra             2.363129e+09
# 2                        uttar-pradesh             1.740346e+09
# 3                           tamil-nadu             1.555507e+09
# 4                               kerala             1.313719e+09
# 5                            telangana             1.171060e+09
# 6                          west-bengal             1.052463e+09
# 7                            rajasthan             9.596539e+08
# 8                              haryana             8.309812e+08
# 9                                delhi             8.153652e+08
# 10                      andhra-pradesh             8.122230e+08
# 11                             gujarat             7.292334e+08
# 12                      madhya-pradesh             7.111535e+08
# 13                               bihar             6.710568e+08
# ...

# %%
#Transaction Type Trends:
query = """
SELECT 
    state,
    transaction_type,
    COUNT(*) AS transaction_count,
    SUM(transaction_amount) AS total_transaction_value
FROM 
    aggregated_transaction
GROUP BY 
    state, transaction_type
ORDER BY 
    total_transaction_value DESC;
"""

result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#                          State       Transaction_type  transaction_count  \
# 0                    telangana  Peer-to-peer payments                 28
# 1                    karnataka  Peer-to-peer payments                 28
# 2                  maharashtra  Peer-to-peer payments                 28
# 3               andhra-pradesh  Peer-to-peer payments                 28
# 4                    rajasthan  Peer-to-peer payments                 28
# ..                         ...                    ...                ...
# 175                     ladakh                 Others                 28
# 176  andaman-&-nicobar-islands                 Others                 28
# 177                    mizoram                 Others                 28
# 178                lakshadweep     Financial Services                 22
# 179                lakshadweep                 Others                 28
#
#      total_transaction_value
# 0               3.336758e+13
# 1               3.132246e+13
# ...

# %%
#5. User Engagement and Growth Strategy
#Total User Engagement per State 
query = """
SELECT 
    State, 
    Year, 
    Quarter, 
    SUM(Aggregated_count) AS total_engagement
FROM 
    aggregated_user
GROUP BY 
    State, Year, Quarter
ORDER BY 
    total_engagement DESC;
"""

result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#                State  Year  Quarter  total_engagement
# 0          rajasthan  2024        3        5335171033
# 1     madhya-pradesh  2024        3        5313772854
# 2      uttar-pradesh  2024        4        5080900941
# 3        maharashtra  2024        4        5042420660
# 4          rajasthan  2024        2        4962266918
# ...              ...   ...      ...               ...
# 1003     west-bengal  2018        1                 0
# 1004     west-bengal  2018        2                 0
# 1005     west-bengal  2018        3                 0
# 1006     west-bengal  2018        4                 0
# 1007     west-bengal  2019        1                 0
#
# [1008 rows x 4 columns]

# %%
# Insurance Adoption by State
query = """
SELECT State, SUM(transaction_count) AS total_insurance_adoption FROM aggregated_insurance WHERE Transaction_type = 'insurance' GROUP BY State ORDER BY total_insurance_adoption DESC;
"""

result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
# Empty DataFrame
# Columns: [State, total_insurance_adoption]
# Index: []

# %%
query = "PRAGMA table_info (aggregated_insurance);"
table_structure = pd.read_sql_query(query, con=engine)
print(table_structure)
# Out:
#    cid                name    type  notnull dflt_value  pk
# 0    0               State    TEXT        0       None   0
# 1    1                Year    TEXT        0       None   0
# 2    2             Quarter  BIGINT        0       None   0
# 3    3    Transaction_type    TEXT        0       None   0
# 4    4   transaction_count  BIGINT        0       None   0
# 5    5  transaction_amount   FLOAT        0       None   0

# %%
query = "PRAGMA table_info (aggregated_transaction);"
table_structure = pd.read_sql_query(query, con=engine)
print(table_structure)
# Out:
#    cid                name    type  notnull dflt_value  pk
# 0    0               State    TEXT        0       None   0
# 1    1                Year    TEXT        0       None   0
# 2    2             Quarter  BIGINT        0       None   0
# 3    3    Transaction_type    TEXT        0       None   0
# 4    4   transaction_count  BIGINT        0       None   0
# 5    5  transaction_amount   FLOAT        0       None   0

# %%
#Transaction Volume by State
query = """
SELECT 
    State, 
    SUM(transaction_count) AS total_transaction_count
FROM 
    aggregated_transaction
GROUP BY 
    State
ORDER BY 
    total_transaction_count DESC;
"""

result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#                                  State  total_transaction_count
# 0                          maharashtra              31985208732
# 1                            karnataka              30970946279
# 2                            telangana              26174684592
# 3                       andhra-pradesh              18918696723
# 4                        uttar-pradesh              18523603727
# 5                            rajasthan              17108537898
# 6                       madhya-pradesh              14072176059
# 7                                bihar              10941026824
# 8                          west-bengal               9191499687
# 9                               odisha               8918527452
# 10                               delhi               8495316647
# 11                          tamil-nadu               7796386037
# 12                             haryana               6744901124
# 13                             gujarat               6726865334
# ...

# %%
#Top Users by Transaction Volume
query = """
SELECT 
    State, 
    SUM(transaction_count) AS total_transaction_count
FROM 
    aggregated_transaction
GROUP BY 
    State
ORDER BY 
    total_transaction_count DESC;
"""

result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#                                  State  total_transaction_count
# 0                          maharashtra              31985208732
# 1                            karnataka              30970946279
# 2                            telangana              26174684592
# 3                       andhra-pradesh              18918696723
# 4                        uttar-pradesh              18523603727
# 5                            rajasthan              17108537898
# 6                       madhya-pradesh              14072176059
# 7                                bihar              10941026824
# 8                          west-bengal               9191499687
# 9                               odisha               8918527452
# 10                               delhi               8495316647
# 11                          tamil-nadu               7796386037
# 12                             haryana               6744901124
# 13                             gujarat               6726865334
# ...

# %%
#6.Insurance Engagement Analysis
#Total Insurance Transactions by State
query = """
SELECT State, SUM(transaction_count) AS total_transactions, SUM(transaction_amount) AS total_amount
FROM aggregated_insurance
GROUP BY State;
"""

result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#                                  State  total_transactions  total_amount
# 0            andaman-&-nicobar-islands               12997  1.938679e+07
# 1                       andhra-pradesh              697769  8.122230e+08
# 2                    arunachal-pradesh               10214  2.342076e+07
# 3                                assam              262818  4.118310e+08
# 4                                bihar              536592  6.710568e+08
# 5                           chandigarh               22079  3.328588e+07
# 6                         chhattisgarh              189517  2.743449e+08
# 7   dadra-&-nagar-haveli-&-daman-&-diu               13792  1.799241e+07
# 8                                delhi              652514  8.153652e+08
# 9                                  goa               59872  8.373000e+07
# 10                             gujarat              562595  7.292334e+08
# 11                             haryana              573738  8.309812e+08
# ...

# %%
#Insurance Transaction Trends (Year and Quarter)
query = """
SELECT Year, Quarter, SUM(transaction_count) AS total_transactions, SUM(transaction_amount) AS total_amount
FROM aggregated_insurance
GROUP BY Year, Quarter
ORDER BY Year, Quarter;
"""

result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#     Year  Quarter  total_transactions  total_amount
# 0   2020        2              185348  3.373217e+07
# 1   2020        3              354284  8.949508e+07
# 2   2020        4              248626  1.709799e+08
# 3   2021        1              318115  2.062957e+08
# 4   2021        2              363988  2.950654e+08
# 5   2021        3              374860  3.423888e+08
# 6   2021        4              526319  6.554201e+08
# 7   2022        1              617575  8.874138e+08
# 8   2022        2              630744  8.570128e+08
# 9   2022        3              806454  1.054673e+09
# 10  2022        4             1035343  1.439744e+09
# 11  2023        1              923147  1.408777e+09
# 12  2023        2              893809  1.347353e+09
# 13  2023        3             1010192  1.445209e+09
# 14  2023        4             1159039  1.855267e+09
# 15  2024        1             1273761  1.931922e+09
# 16  2024        2             1105025  1.759607e+09
# ...

# %%
#Total Number of Users Engaging in Insurance by State
query = """
SELECT State, SUM(Aggregated_count) AS total_users_engaged
FROM aggregated_user
GROUP BY State;
"""

result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#                                  State  total_users_engaged
# 0            andaman-&-nicobar-islands            170043693
# 1                       andhra-pradesh          24728024309
# 2                    arunachal-pradesh           1117277209
# 3                                assam           9436508709
# 4                                bihar          13608259251
# 5                           chandigarh            172230820
# 6                         chhattisgarh          11190410814
# 7   dadra-&-nagar-haveli-&-daman-&-diu            207734903
# 8                                delhi           4847106329
# 9                                  goa            528329279
# 10                             gujarat          20780416980
# 11                             haryana           8259126213
# 12                    himachal-pradesh           2197083175
# 13                     jammu-&-kashmir           2709558059
# 14                           jharkhand          10907909802
# ...

# %%
#User Engagement Over Time (Year and Quarter)
query = """
SELECT Year, Quarter, SUM(Aggregated_count) AS total_users_engaged
FROM aggregated_user
GROUP BY Year, Quarter
ORDER BY Year, Quarter;
"""

result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#     Year  Quarter  total_users_engaged
# 0   2018        1                    0
# 1   2018        2                    0
# 2   2018        3                    0
# 3   2018        4                    0
# 4   2019        1                    0
# 5   2019        2            920409531
# 6   2019        3           3448355858
# 7   2019        4           4301061532
# 8   2020        1           4768934587
# 9   2020        2           4357622260
# 10  2020        3           5739306412
# 11  2020        4           7461591732
# 12  2021        1           8635472151
# 13  2021        2           9630577372
# 14  2021        3          12256310935
# 15  2021        4          15172448895
# 16  2022        1          15724113184
# 17  2022        2          17786561637
# 18  2022        3          19223220607
# 19  2022        4          21262576442
# 20  2023        1          22927454612
# 21  2023        2          24931083989
# 22  2023        3          27224991203
# ...

# %%
#7.Transaction Analysis Across States and Districts
#Top States
query = """
SELECT 
    State,
    SUM(Metric_count) AS total_transactions,
    SUM(Metric_amount) AS total_amount
FROM 
    map_transaction
GROUP BY 
    State
ORDER BY 
    total_amount DESC
LIMIT 10;
"""

result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#             State  total_transactions  total_amount
# 0       telangana         26174684592  4.165596e+13
# 1       karnataka         30970946279  4.067872e+13
# 2     maharashtra         31985208732  4.037420e+13
# 3  andhra-pradesh         18918696723  3.466908e+13
# 4   uttar-pradesh         18523603727  2.688521e+13
# 5       rajasthan         17108537898  2.634324e+13
# 6  madhya-pradesh         14072176059  1.912528e+13
# 7           bihar         10941026824  1.790135e+13
# 8     west-bengal          9191499687  1.558416e+13
# 9          odisha          8918527452  1.226398e+13

# %%
#Top Districts
query = """
SELECT 
    State,
    Level AS District,
    SUM(Metric_count) AS total_transactions,
    SUM(Metric_amount) AS total_amount
FROM 
    top_transaction
GROUP BY 
    State, District
ORDER BY 
    total_amount DESC
LIMIT 10;

"""

result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#             State  District  total_transactions  total_amount
# 0       telangana  District         21131021998  3.245953e+13
# 1       karnataka  District         24185088364  3.014755e+13
# 2  andhra-pradesh  District         15245589058  2.797994e+13
# 3     maharashtra  District         23249830825  2.790584e+13
# 4       rajasthan  District         11214587865  1.709694e+13
# 5     west-bengal  District          6839993302  1.170470e+13
# 6   uttar-pradesh  District          8677237949  1.137258e+13
# 7           delhi  District          8162294853  1.108040e+13
# 8       telangana   Pincode          7155782848  1.088543e+13
# 9  madhya-pradesh  District          8114456875  1.054562e+13

# %%
#Top Pin Codes
query = """
SELECT 
    State,
    Level AS Pincode,
    SUM(Metric_count) AS total_transactions,
    SUM(Metric_amount) AS total_amount
FROM 
    top_transaction
GROUP BY 
    State, Pincode
ORDER BY 
    total_amount DESC
LIMIT 10;

"""

result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#             State   Pincode  total_transactions  total_amount
# 0       telangana  District         21131021998  3.245953e+13
# 1       karnataka  District         24185088364  3.014755e+13
# 2  andhra-pradesh  District         15245589058  2.797994e+13
# 3     maharashtra  District         23249830825  2.790584e+13
# 4       rajasthan  District         11214587865  1.709694e+13
# 5     west-bengal  District          6839993302  1.170470e+13
# 6   uttar-pradesh  District          8677237949  1.137258e+13
# 7           delhi  District          8162294853  1.108040e+13
# 8       telangana   Pincode          7155782848  1.088543e+13
# 9  madhya-pradesh  District          8114456875  1.054562e+13

# %%
#8.User Registration Analysis
# Top States by Registered Users
query = """
SELECT 
    Year,
    Quarter,
    State,
    SUM(RegisteredUsers) AS total_registered_users
FROM 
    top_user
GROUP BY 
    Year, Quarter, State
ORDER BY 
    Year, Quarter, total_registered_users DESC;
"""

result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#       Year  Quarter                      State  total_registered_users
# 0     2018        1                maharashtra                 4713091
# 1     2018        1                  karnataka                 3418294
# 2     2018        1             andhra-pradesh                 3176099
# 3     2018        1                  telangana                 3041107
# 4     2018        1              uttar-pradesh                 2836054
# ...    ...      ...                        ...                     ...
# 1003  2024        4                     sikkim                  571236
# 1004  2024        4                    mizoram                  373796
# 1005  2024        4                     ladakh                  371863
# 1006  2024        4  andaman-&-nicobar-islands                  328901
# 1007  2024        4                lakshadweep                   23538
#
# [1008 rows x 4 columns]

# %%
#Top Districts by Registered Users 
query = """
SELECT 
    Year,
    Quarter,
    State,
    SUM(RegisteredUsers) AS total_registered_users
FROM 
    top_user
WHERE 
    Level = 'District'
GROUP BY 
    Year, Quarter, State
ORDER BY 
    Year, Quarter, total_registered_users DESC;
"""

result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#       Year  Quarter                      State  total_registered_users
# 0     2018        1                maharashtra                 4224599
# 1     2018        1             andhra-pradesh                 2876906
# 2     2018        1                  karnataka                 2833078
# 3     2018        1                  telangana                 2530788
# 4     2018        1              uttar-pradesh                 2311040
# ...    ...      ...                        ...                     ...
# 1003  2024        4                     sikkim                  320748
# 1004  2024        4                    mizoram                  231656
# 1005  2024        4                     ladakh                  193724
# 1006  2024        4  andaman-&-nicobar-islands                  178788
# 1007  2024        4                lakshadweep                   11769
#
# [1008 rows x 4 columns]

# %%
#Top Pincodes by Registered Users
query = """
SELECT 
    Year,
    Quarter,
    State,
    SUM(RegisteredUsers) AS total_registered_users
FROM 
    top_user
WHERE 
    Level = 'Pincode'
GROUP BY 
    Year, Quarter, State
ORDER BY 
    Year, Quarter, total_registered_users DESC;
"""

result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#       Year  Quarter                      State  total_registered_users
# 0     2018        1                      delhi                  587337
# 1     2018        1                  karnataka                  585216
# 2     2018        1              uttar-pradesh                  525014
# 3     2018        1                  telangana                  510319
# 4     2018        1                maharashtra                  488492
# ...    ...      ...                        ...                     ...
# 1003  2024        4                     sikkim                  250488
# 1004  2024        4                     ladakh                  178139
# 1005  2024        4  andaman-&-nicobar-islands                  150113
# 1006  2024        4                    mizoram                  142140
# 1007  2024        4                lakshadweep                   11769
#
# [1008 rows x 4 columns]

# %%
#9. Insurance Transactions Analysis
#Top States by Insurance Transactions
query = """
SELECT 
    Year, 
    Quarter, 
    State, 
    SUM(Insurance_count) AS total_transactions
FROM top_insurance
GROUP BY Year, Quarter, State
ORDER BY Year, Quarter, total_transactions DESC;
"""

result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#      Year  Quarter           State  total_transactions
# 0    2020        2     maharashtra               39503
# 1    2020        2       karnataka               31032
# 2    2020        2  andhra-pradesh               23143
# 3    2020        2       telangana               20574
# 4    2020        2           delhi               15230
# ..    ...      ...             ...                 ...
# 677  2024        4        nagaland                 995
# 678  2024        4         mizoram                 848
# 679  2024        4          ladakh                 826
# 680  2024        4         manipur                 586
# 681  2024        4     lakshadweep                 318
#
# [682 rows x 4 columns]

# %%
#Top Districts by Insurance Transactions
query = """
SELECT 
    Year, 
    Quarter, 
    State, 
    SUM(Insurance_count) AS total_transactions
FROM top_insurance
WHERE Level = 'District'
GROUP BY Year, Quarter, State
ORDER BY Year, Quarter, total_transactions DESC;
"""

result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#      Year  Quarter           State  total_transactions
# 0    2020        2     maharashtra               34189
# 1    2020        2       karnataka               24400
# 2    2020        2  andhra-pradesh               19896
# 3    2020        2       telangana               16604
# 4    2020        2           delhi               11397
# ..    ...      ...             ...                 ...
# 677  2024        4        nagaland                 558
# 678  2024        4         mizoram                 489
# 679  2024        4          ladakh                 429
# 680  2024        4         manipur                 377
# 681  2024        4     lakshadweep                 159
#
# [682 rows x 4 columns]

# %%
#Top Pin Codes by Insurance Transactions
query = """
SELECT 
    Year, 
    Quarter, 
    State, 
    SUM(Insurance_count) AS total_transactions
FROM top_insurance
WHERE Level = 'Pincode'
GROUP BY Year, Quarter, State
ORDER BY Year, Quarter, total_transactions DESC;
"""

result_df = pd.read_sql_query(query, con=engine)
print(result_df)
# Out:
#      Year  Quarter           State  total_transactions
# 0    2020        2       karnataka                6632
# 1    2020        2     maharashtra                5314
# 2    2020        2       telangana                3970
# 3    2020        2           delhi                3833
# 4    2020        2  andhra-pradesh                3247
# ..    ...      ...             ...                 ...
# 677  2024        4        nagaland                 437
# 678  2024        4          ladakh                 397
# 679  2024        4         mizoram                 359
# 680  2024        4         manipur                 209
# 681  2024        4     lakshadweep                 159
#
# [682 rows x 4 columns]

# %%
import json
import csv
from pathlib import Path

# Define the notebook file path (you can change this accordingly)
notebook_path = Path("PHONEPE (1).ipynb")
output_csv_path = notebook_path.with_name("PHONEPE_outputs_final.csv")

# Load the .ipynb file
with open(notebook_path, "r", encoding="utf-8") as f:
    notebook = json.load(f)

# Extract only the outputs
outputs_only = []

for cell in notebook.get("cells", []):
    if cell.get("cell_type") == "code":
        for output in cell.get("outputs", []):
            if output.get("output_type") == "stream":
                outputs_only.append(["".join(output.get("text", []))])
            elif output.get("output_type") == "execute_result":
                data = output.get("data", {})
                outputs_only.append(["".join(data.get("text/plain", []))])
            elif output.get("output_type") == "error":
                outputs_only.append(["\n".join(output.get("traceback", []))])

# Save outputs to CSV
with open(output_csv_path, "w", newline='', encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["output"])
    writer.writerows(outputs_only)

# %%
import sqlite3
import pandas as pd

# Connect using sqlite3
conn = sqlite3.connect('phonepe_data.db')
cursor = conn.cursor()

# Get table names
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = [row[0] for row in cursor.fetchall()]

# Export each table
for table in tables:
    df = pd.read_sql_query(f"SELECT * FROM {table}", conn)
    df.to_csv(f"{table}.csv", index=False)
    print(f"Exported {table}.csv")

conn.close()
# Out:
# Exported aggregated_transaction.csv
# Exported aggregated_insurance.csv
# Exported aggregated_user.csv
# Exported map_transaction.csv
# Exported map_insurance.csv
# Exported map_user.csv
# Exported top_transaction.csv
# Exported top_insurance.csv
# Exported top_user.csv
